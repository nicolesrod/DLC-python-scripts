# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# CSV FILE

# %%
CollectedData = pd.read_csv('../Mystuff/CollectedData_Nicole Rodriguez.csv')
csv2 = pd.read_csv('../Mystuff/CollectedData_Nicole Rodriguez.csv')
CollectedData.head(84)
# Out:
#                                         scorer    Nicole Rodriguez  \
# 0                                    bodyparts              RF paw
# 1                                       coords                   x
# 2   labeled-data/Cgroup_tone001OFF/img0126.png   450.9039744288118
# 3   labeled-data/Cgroup_tone001OFF/img0317.png   450.4164241500637
# 4   labeled-data/Cgroup_tone001OFF/img0357.png   458.7245204618286
# ..                                         ...                 ...
# 79   labeled-data/Cgroup_tone002ON/img3068.png    499.354732795379
# 80   labeled-data/Cgroup_tone002ON/img3123.png   495.5723213675881
# 81   labeled-data/Cgroup_tone002ON/img3559.png    500.823719105838
# 82           labeled-data/tone001off/image.png                 NaN
# 83         labeled-data/tone001off/img0085.png  241.80922667543908
#
#     Nicole Rodriguez.1  Nicole Rodriguez.2  Nicole Rodriguez.3  \
# 0               RF paw              LF paw              LF paw
# 1                    y                   x                   y
# 2    320.2241388922715   451.2521470186125   297.2447479654281
# 3    297.6016932811391  430.90523785560345   280.0240479708146
# 4    310.2904138364587   461.5506907496282   291.2137643938116
# ..                 ...                 ...                 ...
# 79  232.20541629670106   484.0677207840995  234.90312429869152
# 80  223.89551218342677   483.7537910731535   233.2518486665208
# 81   227.1846819596632  482.46431742562487  229.02062212768453
# 82                 NaN                 NaN                 NaN
# 83  378.73940179172547  261.36760968987016   381.9991322941306
#
#     Nicole Rodriguez.4  Nicole Rodriguez.5  Nicole Rodriguez.6  \
# 0               RR paw              RR paw              LR paw
# 1                    x                   y                   x
# 2    418.8720961671513   309.4307886084511   428.9691012713704
# 3    420.8859800287185  307.62095110802403   402.4294524528778
# 4   423.86842024563396   280.6156258145632  418.68710805133475
# ..                 ...                 ...                 ...
# 79   502.7268677978671   258.5080693161084   484.2925297842654
# 80  500.98914775253724  258.85866430446237  479.32184221274053
# 81  501.34827343955834    252.101012811381  479.57926859016277
# 82                 NaN                 NaN                 NaN
# 83  244.13760560572848  348.00479991190514   271.6124769831436
#
#     Nicole Rodriguez.7  Nicole Rodriguez.8  Nicole Rodriguez.9  \
# 0               LR paw                nose                nose
# 1                    y                   x                   y
# 2   284.01418955300306  470.05346686784804  303.16368199203924
# 3    289.3401999852866   454.4592825714383  273.69609565909775
# 4     308.170786120609   486.7507091491743  310.29041383645864
# ..                 ...                 ...                 ...
# 79   259.8569233171036   479.7963497809479  207.70123527862071
# 80  252.70317977611103   466.7646537749038  209.61478807765172
# 81  252.88784431196154  492.69312693317215   200.6946881067843
# 82                 NaN                 NaN                 NaN
# 83  337.29425683257386   235.2897656706287  404.35157002490905
#
#    Nicole Rodriguez.10 Nicole Rodriguez.11 Nicole Rodriguez.12  \
# 0       middle of body      middle of body            tailbase
# 1                    x                   y                   x
# 2    434.1916901183803  303.16368199203924   405.6415377547263
# 3   427.56548524664186  293.91038776597094   402.7810053590843
# 4    442.7095554976311  297.33713335071064   408.7955120440363
# ..                 ...                 ...                 ...
# 79  494.85855279206146  247.94204630831226   494.1841257915639
# 80  495.07988260531994   242.3619657684808   494.0950050807837
# 81  492.69312693317215  239.24943163523182   494.0045127674731
# 82                 NaN                 NaN                 NaN
# 83  253.45112132688615   365.2348039960468  255.77950025717556
#
#    Nicole Rodriguez.13 Nicole Rodriguez.14 Nicole Rodriguez.15  \
# 0             tailbase               L ear               L ear
# 1                    y                   x                   y
# 2   291.32581393881685  456.82290845542303   300.0301286838333
# 3    296.3712581094164    438.463625339043   280.9029302363308
# 4   293.56890630031126   472.3843435195265   296.3950765881108
# ..                 ...                 ...                 ...
# 79   271.5469913257291    483.168484783436   227.0348092928859
# 80   272.8931690291034   477.3520871636681  224.63417032682895
# 81   267.3130884892718   481.4152087581841   219.5786441207178
# 82                 NaN                 NaN                 NaN
# 83   333.1031747580529   243.6719298196706  397.36643323404076
#
#    Nicole Rodriguez.16 Nicole Rodriguez.17
# 0                R ear               R ear
# 1                    x                   y
# 2   455.77839068602105   314.3052048656603
# 3     448.482883165928    289.691752891493
# 4    470.5002299943268   310.2904138364587
# ..                 ...                 ...
# 79  496.20740679305675  223.21305629006605
# 80   488.4319593147005  211.33832374559006
# 81   498.2009474372361  218.00498111955665
# 82                 NaN                 NaN
# 83  236.68679302880236  387.58724172682525
#
# [84 rows x 19 columns]

# %%
CollectedData1 = pd.read_csv('../Mystuff/CollectedData_Nicole Rodriguez2.csv')
csv3 = pd.read_csv('../Mystuff/CollectedData_Nicole Rodriguez2.csv')
CollectedData1.head(84)
# Out:
#                                         scorer Nicole Rodriguez  \
# 0                                    bodyparts           RF paw
# 1                                       coords                x
# 2   labeled-data/Cgroup_tone001OFF/img0126.png      450.9039744
# 3   labeled-data/Cgroup_tone001OFF/img0317.png      450.4164242
# 4   labeled-data/Cgroup_tone001OFF/img0357.png      458.7245205
# ..                                         ...              ...
# 79   labeled-data/Cgroup_tone002ON/img3068.png      499.3547328
# 80   labeled-data/Cgroup_tone002ON/img3123.png      495.5723214
# 81   labeled-data/Cgroup_tone002ON/img3559.png      500.8237191
# 82         labeled-data/tone001off/img0085.png      241.8092267
# 83         labeled-data/tone001off/img0140.png      314.0999061
#
#    Nicole Rodriguez.1 Nicole Rodriguez.2 Nicole Rodriguez.3  \
# 0              RF paw             LF paw             LF paw
# 1                   y                  x                  y
# 2         320.2241389         451.252147         297.244748
# 3         297.6016933        430.9052379         280.024048
# 4         310.2904138        461.5506907        291.2137644
# ..                ...                ...                ...
# 79        232.2054163        484.0677208        234.9031243
# 80        223.8955122        483.7537911        233.2518487
# 81         227.184682        482.4643174        229.0206221
# 82        378.7394018        261.3676097        381.9991323
# 83        410.4829679         326.041546        402.6949418
#
#    Nicole Rodriguez.4 Nicole Rodriguez.5 Nicole Rodriguez.6  \
# 0              RR paw             RR paw             LR paw
# 1                   x                  y                  x
# 2         418.8720962        309.4307886        428.9691013
# 3           420.88598        307.6209511        402.4294525
# 4         423.8684202        280.6156258        418.6871081
# ..                ...                ...                ...
# 79        502.7268678        258.5080693        484.2925298
# 80        500.9891478        258.8586643        479.3218422
# 81        501.3482734        252.1010128        479.5792686
# 82        244.1376056        348.0047999         271.612477
# 83        286.0630122        400.6181348        279.0537887
#
#    Nicole Rodriguez.7 Nicole Rodriguez.8 Nicole Rodriguez.9  \
# 0              LR paw               nose               nose
# 1                   y                  x                  y
# 2         284.0141896        470.0534669         303.163682
# 3            289.3402        454.4592826        273.6960957
# 4         308.1707861        486.7507091        310.2904138
# ..                ...                ...                ...
# 79        259.8569233        479.7963498        207.7012353
# 80        252.7031798        466.7646538        209.6147881
# 81        252.8878443        492.6931269        200.6946881
# 82        337.2942568        235.2897657          404.35157
# 83        368.4276271        345.7712121           420.0882
#
#    Nicole Rodriguez.10 Nicole Rodriguez.11 Nicole Rodriguez.12  \
# 0       middle of body      middle of body            tailbase
# 1                    x                   y                   x
# 2          434.1916901          303.163682         405.6415378
# 3          427.5654852         293.9103878         402.7810054
# 4          442.7095555         297.3371334          408.795512
# ..                 ...                 ...                 ...
# 79         494.8585528         247.9420463         494.1841258
# 80         495.0798826         242.3619658         494.0950051
# 81         492.6931269         239.2494316         494.0045128
# 82         253.4511213          365.234804         255.7795003
# 83         306.0522791         397.5029244         275.9385783
#
#    Nicole Rodriguez.13 Nicole Rodriguez.14 Nicole Rodriguez.15  \
# 0             tailbase               L ear               L ear
# 1                    y                   x                   y
# 2          291.3258139         456.8229085         300.0301287
# 3          296.3712581         438.4636253         280.9029302
# 4          293.5689063         472.3843435         296.3950766
# ..                 ...                 ...                 ...
# 79         271.5469913         483.1684848         227.0348093
# 80          272.893169         477.3520872         224.6341703
# 81         267.3130885         481.4152088         219.5786441
# 82         333.1031748         243.6719298         397.3664332
# 83         384.2632801         334.8679756         407.6273583
#
#    Nicole Rodriguez.16 Nicole Rodriguez.17
# 0                R ear               R ear
# 1                    x                   y
# 2          455.7783907         314.3052049
# 3          448.4828832         289.6917529
# 4            470.50023         310.2904138
# ..                 ...                 ...
# 79         496.2074068         223.2130563
# 80         488.4319593         211.3383237
# 81         498.2009474         218.0049811
# 82          236.686793         387.5872417
# 83         325.2627434         419.3093974
#
# [84 rows x 19 columns]

# %% [markdown]
# # Dataframes

# %%
dlc_data = CollectedData1.iloc[2:,]
dlc_data = dlc_data.rename( columns = {'scorer':'image', 
                            'Nicole Rodriguez':'RF paw (x)', 
                            'Nicole Rodriguez.1':'RF paw (y)', 
                            'Nicole Rodriguez.2':'LF paw (x)',
                            'Nicole Rodriguez.3':'LF paw (y)',
                            'Nicole Rodriguez.4':'RR paw (x)',
                            'Nicole Rodriguez.5':'RR paw (y)',
                            'Nicole Rodriguez.6':'LR paw (x)',
                            'Nicole Rodriguez.7':'LR paw (y)',
                            'Nicole Rodriguez.8':'snout (x)',
                            'Nicole Rodriguez.9':'snout (y)',
                            'Nicole Rodriguez.10':'middle of body (x)',
                                  'Nicole Rodriguez.11':'middle of body (y)',
                                  'Nicole Rodriguez.12':'tailbase (x)', 
                                  'Nicole Rodriguez.13':'tailbase (y)',
                                  'Nicole Rodriguez.14':'L ear (x)',
                                  'Nicole Rodriguez.15':'L ear (y)',
                                  'Nicole Rodriguez.16':'R ear (x)',
                                  'Nicole Rodriguez.17':'R ear (y)'})

# %%
coordinates = dlc_data.iloc [:, 1:17]

coordinates.iloc[:,] = coordinates.iloc[:,].astype(str).astype(float)
# Out:
# /opt/conda/envs/new_env/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /opt/conda/envs/new_env/lib/python3.7/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
### snout dataframe

snout = dlc_data.iloc[:,[9,10]]
snout

snout['snout (x)'] = snout ['snout (x)'].astype(str).astype(float)
snout['snout (y)'] = snout ['snout (y)'].astype(str).astype(float)
# Out:
# /opt/conda/envs/new_env/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/envs/new_env/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
### RF paw dataframe

RF_paw = dlc_data.iloc[:,[1,2]]
RF_paw

RF_paw['RF paw (x)'] = RF_paw ['RF paw (x)'].astype(str).astype(float)
RF_paw['RF paw (y)'] = RF_paw ['RF paw (y)'].astype(str).astype(float)


### RR paw dataframe

RR_paw = dlc_data.iloc[:,[5,6]]
RR_paw

RR_paw['RR paw (x)'] = RR_paw ['RR paw (x)'].astype(str).astype(float)
RR_paw['RR paw (y)'] = RR_paw ['RR paw (y)'].astype(str).astype(float)
# Out:
# /opt/conda/envs/new_env/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/envs/new_env/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/conda/envs/new_env/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /opt/conda/envs/new_env/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
### LF paw dataframe

LF_paw = dlc_data.iloc[:,[3,4]]

LF_paw['LF paw (x)'] = LF_paw ['LF paw (x)'].astype(str).astype(float)
LF_paw['LF paw (y)'] = LF_paw ['LF paw (y)'].astype(str).astype(float)


### LR paw dataframe

LR_paw = dlc_data.iloc[:,[7,8]]

LR_paw['LR paw (x)'] = LR_paw ['LR paw (x)'].astype(str).astype(float)
LR_paw['LR paw (y)'] = LR_paw ['LR paw (y)'].astype(str).astype(float)
# Out:
# /opt/conda/envs/new_env/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/conda/envs/new_env/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/envs/new_env/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /opt/conda/envs/new_env/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Snout video df

# %%
#### Snout

### C Group OFF video 
snout_CgroupOFF1 = snout.iloc[:20,:]
snout_CgroupOFF1

### C Group ON video 
snout_CgroupON1 = snout.iloc[20:40,:]
snout_CgroupON1

## C Group OFF video 
snout_CgroupOFF2 = snout.iloc[40:60,:]
snout_CgroupOFF2

## C Group ON video 
snout_CgroupON2 = snout.iloc[60:80,:]
snout_CgroupON2


### EYFP OFF video (ALL)
snout_CgroupOFF = snout.iloc[:20,:]
snout_CgroupOFF = snout_CgroupOFF.append(snout.iloc[40:60,:])
snout_CgroupOFF

### EYFP ON video (ALL)
snout_CgroupON = snout.iloc[20:40,:]
snout_CgroupON = snout_CgroupON.append(snout.iloc[60:80,:])
snout_CgroupON


### EYFP video (ALL)
snout_Cgroup = snout.iloc[:80,:]
snout_Cgroup


### Arch1 OFF video
snout_OFF1 = snout.iloc[80:100,:]
snout_OFF1

### Arch1 ON video
snout_ON1 = snout.iloc[100:120,:]
snout_ON1

### tone 2 OFF video
snout_OFF2 = snout.iloc[120:140,:]
snout_OFF2

### tone 2 ON video
snout_ON2 = snout.iloc[140: ,:]
snout_ON2

### Arch OFF (ALL) video
snout_OFF =  snout.iloc[80:100,:]
snout_OFF =  snout_OFF.append(snout.iloc[120:140,:])
snout_OFF

### Arch ON (ALL) video
snout_ON = snout.iloc[100:120,:]
snout_ON = snout_ON.append(snout.iloc[140: ,:])
snout_ON

### arch (ALL) video
snout_tone = snout.iloc[80:, :]
snout_tone
# Out:
#       snout (x)   snout (y)
# 82   235.289766  404.351570
# 83   345.771212  420.088200
# 84   328.077804  140.398308
# 85   198.254892  225.087803
# 86   217.129280  217.115112
# ..          ...         ...
# 156  189.944753  251.158956
# 157  229.487084  217.333230
# 158  220.536541  133.814011
# 159  220.216891  186.637435
# 160  222.090768  130.928962
#
# [79 rows x 2 columns]

# %% [markdown]
# ## RF paw videos df

# %%
#### RF paw

### C Group OFF video 
RF_paw_CgroupOFF1 = RF_paw.iloc[:20,:]
RF_paw_CgroupOFF1

### C Group ON video 
RF_paw_CgroupON1 = RF_paw.iloc[20:40,:]
RF_paw_CgroupON1

## C Group OFF video 
RF_paw_CgroupOFF2 = RF_paw.iloc[40:60,:]
RF_paw_CgroupOFF2

## C Group ON video 
RF_paw_CgroupON2 = RF_paw.iloc[60:80,:]
RF_paw_CgroupON2


### C Group OFF video (ALL)
RF_paw_CgroupOFF = RF_paw.iloc[:20,:]
RF_paw_CgroupOFF = RF_paw_CgroupOFF.append(RF_paw.iloc[40:60,:])
RF_paw_CgroupOFF

### C Group ON video (ALL)
RF_paw_CgroupON = RF_paw.iloc[20:40,:]
RF_paw_CgroupON = RF_paw_CgroupON.append(RF_paw.iloc[60:80,:])
RF_paw_CgroupON


###C Group video (ALL)
RF_paw_Cgroup = RF_paw.iloc[:80,:]
RF_paw_Cgroup

### tone 1 OFF video
RF_paw_OFF1 = RF_paw.iloc[80:100,:]
RF_paw_OFF1

### tone 1 ON video 
RF_paw_ON1 = RF_paw.iloc[100:120,:]
RF_paw_ON1

### tone 2 OFF video
RF_paw_OFF2 = RF_paw.iloc[120:140,:]
RF_paw_OFF2

### tone 2 ON video
RF_paw_ON2 = RF_paw.iloc[140: ,:]
RF_paw_ON2


### tone OFF (ALL) video
RF_paw_OFF =  RF_paw.iloc[80:100,:]
RF_paw_OFF =  RF_paw_OFF.append(RF_paw.iloc[121:141,:])
RF_paw_OFF

### tone ON (ALL) video
RF_paw_ON = RF_paw.iloc[100:120,:]
RF_paw_ON = RF_paw_ON.append(RF_paw.iloc[140: ,:])
RF_paw_ON

### tone (ALL) video
RF_paw_tone = RF_paw.iloc[80:, :]
RF_paw_tone
# Out:
#      RF paw (x)  RF paw (y)
# 82   241.809227  378.739402
# 83   314.099906  410.482968
# 84   308.089993  137.934057
# 85   180.591327  203.409792
# 86   192.201240  217.630300
# ..          ...         ...
# 156  168.561135  233.415103
# 157  198.094113  220.657192
# 158  212.256076  155.245802
# 159  199.689688  170.285256
# 160  212.142969  153.185053
#
# [79 rows x 2 columns]

# %% [markdown]
# ## RR paw video df

# %%
#### RR paw

### C Group OFF video 
RR_paw_CgroupOFF1 = RR_paw.iloc[:20,:]
RR_paw_CgroupOFF1

### C Group ON video 
RR_paw_CgroupON1 = RR_paw.iloc[20:40,:]
RR_paw_CgroupON1

## C Group OFF video 
RR_paw_CgroupOFF2 = RR_paw.iloc[40:60,:]
RR_paw_CgroupOFF2

## C Group ON video 
RR_paw_CgroupON2 = RR_paw.iloc[60:80,:]
RR_paw_CgroupON2


### C Group OFF video (ALL)
RR_paw_CgroupOFF = RR_paw.iloc[:20,:]
RR_paw_CgroupOFF = RR_paw_CgroupOFF.append(RR_paw.iloc[40:60,:])
RR_paw_CgroupOFF

### C Group ON video (ALL)
RR_paw_CgroupON = RR_paw.iloc[20:40,:]
RR_paw_CgroupON = RR_paw_CgroupON.append(RR_paw.iloc[60:80,:])
RR_paw_CgroupON

###C Group video (ALL)
RR_paw_Cgroup = RR_paw.iloc[:80,:]
RR_paw_Cgroup


### tone 1 OFF video
RR_paw_OFF1 = RR_paw.iloc[80:100,:]
RR_paw_OFF1

### tone 1 ON video 
RR_paw_ON1 = RR_paw.iloc[100:120,:]
RR_paw_ON1

### tone 2 OFF video
RR_paw_OFF2 = RR_paw.iloc[120:140,:]
RR_paw_OFF2

### tone 2 ON video
RR_paw_ON2 = RR_paw.iloc[140: ,:]
RR_paw_ON2


### tone OFF (ALL) video
RR_paw_OFF =  RR_paw.iloc[80:100,:]
RR_paw_OFF =  RR_paw_OFF.append(RR_paw.iloc[120:140,:])
RR_paw_OFF

### tone ON (ALL) video
RR_paw_ON = RR_paw.iloc[100:120,:]
RR_paw_ON = RR_paw_ON.append(RR_paw.iloc[140: ,:])
RR_paw_ON

### tone (ALL) video
RR_paw_tone = RR_paw.iloc[80:, :]
RR_paw_tone
# Out:
#      RR paw (x)  RR paw (y)
# 82   244.137606  348.004800
# 83   286.063012  400.618135
# 84   254.150284  136.017418
# 85   176.576881  181.196522
# 86   179.049914  201.069370
# ..          ...         ...
# 156  159.916694  204.524470
# 157  175.934369  221.580515
# 158  202.514353  171.563188
# 159  186.642737  160.891452
# 160  197.305575  166.504986
#
# [79 rows x 2 columns]

# %% [markdown]
# ## LF paw video df

# %%
#### LF paw

### C Group OFF1 video 
LF_paw_CgroupOFF1 = LF_paw.iloc[:20,:]
LF_paw_CgroupOFF1

### C Group ON1 video 
LF_paw_CgroupON1 = LF_paw.iloc[20:40,:]
LF_paw_CgroupON1

## C Group OFF2 video 
LF_paw_CgroupOFF2 = LF_paw.iloc[40:60,:]
LF_paw_CgroupOFF2

## C Group ON2 video 
LF_paw_CgroupON2 = LF_paw.iloc[60:80,:]
LF_paw_CgroupON2

### C Group OFF video (ALL)
LF_paw_CgroupOFF = LF_paw.iloc[:20,:]
LF_paw_CgroupOFF = LF_paw_CgroupOFF.append(LF_paw.iloc[40:60,:])
LF_paw_CgroupOFF

### C Group ON video (ALL)
LF_paw_CgroupON = LF_paw.iloc[20:40,:]
LF_paw_CgroupON = LF_paw_CgroupON.append(LF_paw.iloc[60:80,:])
LF_paw_CgroupON

###C Group video (ALL)
LF_paw_Cgroup = LF_paw.iloc[:80,:]
LF_paw_Cgroup



### tone 1 OFF video
LF_paw_OFF1 = LF_paw.iloc[80:100,:]
LF_paw_OFF1

### tone 1 ON video 
LF_paw_ON1 = LF_paw.iloc[100:120,:]
LF_paw_ON1

### tone 2 OFF video
LF_paw_OFF2 = LF_paw.iloc[120:140,:]
LF_paw_OFF2

### tone 2 ON video
LF_paw_ON2 = LF_paw.iloc[140: ,:]
LF_paw_ON2

### tone OFF (ALL) video
LF_paw_OFF =  LF_paw.iloc[80:100,:]
LF_paw_OFF =  LF_paw_OFF.append(LF_paw.iloc[120:140,:])
LF_paw_OFF

### tone ON (ALL) video
LF_paw_ON =  LF_paw.iloc[100:120,:]
LF_paw_ON = LF_paw_ON.append(LF_paw.iloc[140: ,:])
LF_paw_ON

### tone (ALL) video
LF_paw_tone = LF_paw.iloc[80:, :]
LF_paw_tone
# Out:
#      LF paw (x)  LF paw (y)
# 82   261.367610  381.999132
# 83   326.041546  402.694942
# 84   306.994770  110.553495
# 85   196.113854  197.254308
# 86   205.596110  204.722516
# ..          ...         ...
# 156  180.845341  230.457794
# 157  198.648107  206.622687
# 158  203.732068  145.260536
# 159  212.214761  157.238305
# 160  203.881239  142.225614
#
# [79 rows x 2 columns]

# %% [markdown]
# ## LR paw video df

# %%
#### LR paw

### C Group OFF video 
LR_paw_CgroupOFF1 = LR_paw.iloc[:20,:]
LR_paw_CgroupOFF1

### C Group ON video 
LR_paw_CgroupON1 = LR_paw.iloc[20:40,:]
LR_paw_CgroupON1

## C Group OFF video 
LR_paw_CgroupOFF2 = LR_paw.iloc[40:60,:]
LR_paw_CgroupOFF2

## C Group ON video 
LR_paw_CgroupON = LR_paw.iloc[60:80,:]
LR_paw_CgroupON


### C Group OFF video (ALL)
LR_paw_CgroupOFF = LR_paw.iloc[:20,:]
LR_paw_CgroupOFF = LR_paw_CgroupOFF.append(LR_paw.iloc[40:60,:])
LR_paw_CgroupOFF

### C Group ON video (ALL)
LR_paw_CgroupON = LR_paw.iloc[20:40,:]
LR_paw_CgroupON = LR_paw_CgroupON.append(LR_paw.iloc[60:80,:])
LR_paw_CgroupON

###C Group video (ALL)
LR_paw_Cgroup = LR_paw.iloc[:80,:]
LR_paw_Cgroup


### tone 1 OFF video
LR_paw_OFF1 = LR_paw.iloc[80:100,:]
LR_paw_OFF1

### tone 1 ON video 
LR_paw_ON1 = LR_paw.iloc[100:120,:]
LR_paw_ON1

### tone 2 OFF video
LR_paw_OFF2 = LR_paw.iloc[120:140,:]
LR_paw_OFF2

### tone 2 ON video
LR_paw_ON2 = LR_paw.iloc[140: ,:]
LR_paw_ON2


### tone OFF (ALL) video
LR_paw_OFF =  LR_paw.iloc[80:100,:]
LR_paw_OFF =  LR_paw_OFF.append(LR_paw.iloc[120:140,:])
LR_paw_OFF

### tone ON (ALL) video
LR_paw_ON = LR_paw.iloc[100:120,:]
LR_paw_ON = LR_paw_ON.append(LR_paw.iloc[140: ,:])
LR_paw_ON

### tone (ALL) video
LR_paw_tone = LR_paw.iloc[80:, :]
LR_paw_tone
# Out:
#      LR paw (x)  LR paw (y)
# 82   271.612477  337.294257
# 83   279.053789  368.427627
# 84   271.126233  113.839162
# 85   206.016155  167.547404
# 86   197.072102  188.892216
# ..          ...         ...
# 156  183.120194  196.334999
# 157  178.889001  198.312783
# 158  187.414682  160.116664
# 159  196.732379  146.452826
# 160  189.549665  150.150131
#
# [79 rows x 2 columns]

# %% [markdown]
# # Velocity

# %%
##import
import numpy as np
from collections import namedtuple
from scipy.spatial import distance
import pandas as pd
import warnings

# %%
#define
bodyparts = ['RF paw', 'LF paw', 'RR paw', 'LR paw', 'snout', 'middle of body', 'tailbase', 'L ear', 'R ear']

# %%
## calculate velocity

def calc_distance_between_points_in_a_vector_2d(v1):
    if isinstance(v1, dict) or not np.any(v1) or v1 is None:
        raise ValueError('Feature not implemented: cant handle with data format passed to this function')

    # If pandas series were passed, try to get numpy arrays
    try:
        v1, v2 = v1.values, v2.values
    except:  # all good
        pass
    # loop over each pair of points and extract distances
    dist = []
    for n, pos in enumerate(v1):
        # Get a pair of points
        if n == 0:  # get the position at time 0, velocity is 0
            p0 = pos
            dist.append(0)
        else:
            p1 = pos  # get position at current frame

            # Calc distance
            dist.append(np.abs(distance.euclidean(p0, p1)))

            # Prepare for next iteration, current position becomes the old one and repeat
            p0 = p1

    return np.array(dist)

# %% [markdown]
# ## Snout velocity

# %%
## snout OVERALL velocity
snout_np = snout.to_numpy()
snout_np

#snout_np = snout_np[~np.isnan(snout_np)]
snout_np
snout_vel = calc_distance_between_points_in_a_vector_2d(snout_np)

## snout Cgroup velocity
snout_Cgroup_np = snout_Cgroup.to_numpy()
snout_Cgroup_np

#snout_Cgroup_np = snout_Cgroup_np[~np.isnan(snout_Cgroup_np)]
snout_Cgroup_np
snout_Cgroup_vel = calc_distance_between_points_in_a_vector_2d(snout_Cgroup_np)

print(snout_Cgroup_vel)
print (np.average(snout_Cgroup_vel))

## snout tone velocity
snout_tone_np = snout_tone.to_numpy()
snout_tone_np

#snout_tone_np = snout_tone_np[~np.isnan(snout_tone_np)]
snout_tone_np
snout_tone_vel = calc_distance_between_points_in_a_vector_2d(snout_tone_np)

print(snout_tone_vel)
print (np.average(snout_tone_vel))
# Out:
# [  0.          33.33942451  48.8045115   23.67847368  55.01078085
#   27.27602438  30.74731232  16.05776428  36.35872728  40.2273194
#   32.53145773  60.46557993  45.43919722  49.75306634  15.63868942
#   29.55075892  62.78817995  52.79848309  30.07780209   3.19569543
#   14.45123153  43.51495708  68.24644208  66.30225645  74.19388191
#   55.97942808 104.65221538  62.31384444  70.72094629  95.24782503
#   88.44505483  22.33198099  25.00824907 118.66343967  45.70344385
#   61.62857211 116.13369467 102.59368146  73.88104198  38.96677178
#    7.14006173 197.70449186 133.11156684  13.68673148  55.08185928
#  159.92541649  42.0034666   38.18155417  43.95672129  33.79437682
#   74.63922879  87.35154987  37.22334437 193.2042131   36.52276804
#   16.54184024  13.22360829   9.48405967  64.29896897  77.01231074
#    6.94667884  18.23112936  10.23698012  44.0767393   13.68005643
#   32.17863496  98.68636053  23.95572664  81.64493281  60.91294698
#   56.17968493  35.77635939  15.42293012  27.15728196  35.51555279
#   34.55058917  21.57206519  39.81026695  13.17143823  27.41995444]
# 50.92415818477741
# [  0.         111.59655695 280.24898266 155.00419019  20.48917581
#   72.0974938  157.97612951 162.00510091  34.77459894 111.86736218
#   91.40338844  56.79941239  81.64283897  60.61165946  96.87522134
#  137.41900072  77.3188619  180.91433403  47.3523795   32.55723602
#    2.11229782  11.91554708  11.34804866  56.84644073  25.93300751
#    3.56929462  53.27061752  18.87139331  62.88696593  41.23821353
#   98.83924901 242.09716456  47.75567438 153.45058351  25.43849423
#   32.83906749  29.37709989  39.28709841 201.52043687  43.197772
#   40.29418828 233.305869   139.92926345 200.8406214   91.14628444
#  254.45265017  95.41950816 148.27059015 100.63155951 140.506445
#  113.41113275  87.77822376 186.25182581  39.00399318  70.14183497
#   86.12563979  95.6220825    2.99768014 121.73136992  46.88752704
#   51.09979971  95.20771496  65.26024678  86.15994765  38.07481303
#   32.79860667  11.84584838  58.04876441  17.98866063  61.15235927
#  152.63050922  53.65403999  92.68227125  15.82176762  73.00549285
#   52.03629154  83.99745409  52.82439144  55.73998027]
# 83.74083088538852

# %%
####  arch snout vel light off

snout_OFF_np = snout_OFF.to_numpy()
snout_OFF_np
snout_OFF_vel = calc_distance_between_points_in_a_vector_2d(snout_OFF_np)
print(snout_OFF_vel)
print (np.average( snout_OFF_vel))

####  arch snout vel light on

snout_ON_np = snout_ON.to_numpy()
snout_ON_np
snout_ON_vel = calc_distance_between_points_in_a_vector_2d(snout_ON_np)
print(snout_ON_vel)
print (np.average( snout_ON_vel))
# Out:
# [  0.         111.59655695 280.24898266 155.00419019  20.48917581
#   72.0974938  157.97612951 162.00510091  34.77459894 111.86736218
#   91.40338844  56.79941239  81.64283897  60.61165946  96.87522134
#  137.41900072  77.3188619  180.91433403  47.3523795   32.55723602
#  278.25292639 233.305869   139.92926345 200.8406214   91.14628444
#  254.45265017  95.41950816 148.27059015 100.63155951 140.506445
#  113.41113275  87.77822376 186.25182581  39.00399318  70.14183497
#   86.12563979  95.6220825    2.99768014 121.73136992  46.88752704]
# 112.54152378129675
# [  0.          11.91554708  11.34804866  56.84644073  25.93300751
#    3.56929462  53.27061752  18.87139331  62.88696593  41.23821353
#   98.83924901 242.09716456  47.75567438 153.45058351  25.43849423
#   32.83906749  29.37709989  39.28709841 201.52043687  43.197772
#  231.11115185  95.20771496  65.26024678  86.15994765  38.07481303
#   32.79860667  11.84584838  58.04876441  17.98866063  61.15235927
#  152.63050922  53.65403999  92.68227125  15.82176762  73.00549285
#   52.03629154  83.99745409  52.82439144  55.73998027]
# 64.86467900321294

# %%
x = range (40)
y = snout_OFF_vel

plt.title('arch snout velocities (OFF)')
plt.xlabel('number')
plt.ylabel('velocity')
plt.plot(x, y, color = 'orange')
plt.show()

x = range (39)
y = snout_ON_vel

plt.title('arch snout velocities (ON)')
plt.xlabel('number')
plt.ylabel('velocity')
plt.plot(x, y, color = 'chocolate')
plt.show()

# %%
####  non-arch EYFP snout vel light off

snout_CgroupOFF_np = snout_OFF.to_numpy()
snout_CgroupOFF_np
snout_CgroupOFF_vel = calc_distance_between_points_in_a_vector_2d(snout_CgroupOFF_np)
print(snout_CgroupOFF_vel)
print (np.average( snout_CgroupOFF_vel))

####  non-arch EYFP snout vel light on

snout_CgroupON_np = snout_CgroupON.to_numpy()
snout_CgroupON_np
snout_CgroupON_vel = calc_distance_between_points_in_a_vector_2d(snout_CgroupON_np)
print(snout_CgroupON_vel)
print (np.average( snout_CgroupON_vel))
# Out:
# [  0.         111.59655695 280.24898266 155.00419019  20.48917581
#   72.0974938  157.97612951 162.00510091  34.77459894 111.86736218
#   91.40338844  56.79941239  81.64283897  60.61165946  96.87522134
#  137.41900072  77.3188619  180.91433403  47.3523795   32.55723602
#  278.25292639 233.305869   139.92926345 200.8406214   91.14628444
#  254.45265017  95.41950816 148.27059015 100.63155951 140.506445
#  113.41113275  87.77822376 186.25182581  39.00399318  70.14183497
#   86.12563979  95.6220825    2.99768014 121.73136992  46.88752704]
# 112.54152378129675
# [  0.          43.51495708  68.24644208  66.30225645  74.19388191
#   55.97942808 104.65221538  62.31384444  70.72094629  95.24782503
#   88.44505483  22.33198099  25.00824907 118.66343967  45.70344385
#   61.62857211 116.13369467 102.59368146  73.88104198  38.96677178
#  178.2657975   18.23112936  10.23698012  44.0767393   13.68005643
#   32.17863496  98.68636053  23.95572664  81.64493281  60.91294698
#   56.17968493  35.77635939  15.42293012  27.15728196  35.51555279
#   34.55058917  21.57206519  39.81026695  13.17143823  27.41995444]
# 55.07432887401734

# %%
x = range (40)
y = snout_CgroupOFF_vel

plt.title('non-arch EYFP snout velocities (OFF)')
plt.xlabel('number')
plt.ylabel('velocity')
plt.plot(x, y, color = 'red')
plt.show()

x = range (40)
y = snout_CgroupON_vel

plt.title('non-arch EYFP snout velocities (ON)')
plt.xlabel('number')
plt.ylabel('velocity')
plt.plot(x, y, color = 'maroon')
plt.show()

# %% [markdown]
# ## RF paw velocity

# %%
### RF_paw velocity

RF_paw_np = RF_paw.to_numpy()
RF_paw_np

#RF_paw_np = RF_paw_np[~np.isnan(RF_paw_np)]
RF_paw_np
vel = calc_distance_between_points_in_a_vector_2d(RF_paw_np)

## RF paw Cgroup velocity
RF_paw_Cgroup_np = RF_paw_Cgroup.to_numpy()
RF_paw_Cgroup_np

#RF_paw_Cgroup_np = RF_paw_Cgroup_np[~np.isnan(RF_paw_Cgroup_np)]
RF_paw_Cgroup_np
RF_paw_Cgroup_vel = calc_distance_between_points_in_a_vector_2d(RF_paw_Cgroup_np)

print(RF_paw_Cgroup_vel)
print (np.average(RF_paw_Cgroup_vel))

## RF paw tone velocity
RF_paw_tone_np = RF_paw_tone.to_numpy()
RF_paw_tone_np

#RF_paw_tone_np = RF_paw_tone_np[~np.isnan(RF_paw_tone_np)]
RF_paw_tone_np
RF_paw_tone_vel = calc_distance_between_points_in_a_vector_2d(RF_paw_tone_np)

print(RF_paw_tone_vel)
print (np.average(RF_paw_tone_vel))
# Out:
# [  0.          22.62769874  15.16667703  16.10333418  36.15076728
#   15.95358296   5.21049451  13.61469943  30.27205121  24.87394468
#   27.75090031  55.24524295  34.37735889  13.77351353   4.44208901
#   11.25392793  19.98691449  24.0386683   11.85144504   2.40179645
#    9.50001274  16.2757636   11.41338666   2.73593575  39.27533517
#   53.3264037  105.12125302  63.50674834  30.47339312  75.13400685
#   63.1901253   13.89370148  21.35432621  95.96437477  13.12639863
#   52.49087878 119.85625413 118.02419491  28.77720459  40.45270282
#    0.34784754 173.00563471 141.19925218  12.69404104  48.28780893
#  126.60523366  51.25864889  36.94229363  37.88617968   3.12502594
#   65.51200351  81.79852457  44.64729738 189.55897856  12.85140824
#    2.21551984   4.17478567   1.8761433   26.71459029  29.13936414
#    3.36037173   3.24909737   1.42331227  29.99532502  18.90313995
#   26.37999992  64.12061745  14.23956741  80.24878033  41.81691147
#   37.5594279   15.35888564   5.10355343  24.17066809  15.27414636
#   16.47024159   8.45955685  15.40995755   9.13023232   6.19643573]
# 36.07122896941348
# [  0.          78.95312734 272.61516396 143.32822981  18.3579114
#   54.33579719 141.01736236 157.98808773  23.35899684 102.54928884
#   87.43408806   4.51799769 103.50996657  49.25798523  51.5951399
#  151.0324704   67.21935174 140.18775558  42.31755382  10.61215864
#    4.44695435   2.13676293   7.12582418  37.06038471  14.38487115
#    4.1994147   45.58172328  21.42203096  31.61253765  35.99137323
#   56.84950381 244.1744228   23.147584   124.75691447  12.30737106
#   26.10806377   5.99473643  28.93412661 192.674251    31.98987505
#   45.35869568 209.35605632  87.24659414 222.87000429  90.03558692
#  249.25171236  73.65853149 134.85296815  46.15249886 141.27200804
#  105.77660886  58.95355246 185.12666495  34.34886402  59.50821808
#   59.36237579 103.32343525   2.0363542   79.90861656  15.90267931
#   33.01611266  44.49075031  27.94462917  54.06007591  20.91579437
#   12.74419363   4.03519265  50.69638711   6.11752243  58.20588731
#  102.95126137  30.2318765   47.33611428  13.33047695  87.63899098
#   32.17081064  66.9269092   19.59845157  21.15422367]
# 68.21461829980629

# %% [markdown]
# ## RR paw velocity

# %%
### RR paw velocity

RR_paw_np = RR_paw.to_numpy()
RR_paw_np

#RR_paw_np = RR_paw_np[~np.isnan(RR_paw_np)]
RR_paw_np
vel = calc_distance_between_points_in_a_vector_2d(RR_paw_np)

## RR paw Cgroup velocity
RR_paw_Cgroup_np = RR_paw_Cgroup.to_numpy()
RR_paw_Cgroup_np

#RR_paw_Cgroup_np = RR_paw_Cgroup_np[~np.isnan(RR_paw_Cgroup_np)]
RR_paw_Cgroup_np
RR_paw_Cgroup_vel = calc_distance_between_points_in_a_vector_2d(RR_paw_Cgroup_np)

print(RR_paw_Cgroup_vel)
print (np.average(RR_paw_Cgroup_vel))

## RR paw tone velocity
RR_paw_tone_np = RR_paw_tone.to_numpy()
RR_paw_tone_np

#RR_paw_tone_np = RR_paw_tone_np[~np.isnan(RR_paw_tone_np)]
RR_paw_tone_np
RR_paw_tone_vel = calc_distance_between_points_in_a_vector_2d(RR_paw_tone_np)

print(RR_paw_tone_vel)
print (np.average(RR_paw_tone_vel))
# Out:
# [  0.           2.70762622  27.16951498  27.92289613  12.90615402
#    8.99505276   7.29137919  11.44192782  28.09388992  15.94321381
#   22.57384813  39.98953884  41.12046124   4.86921281   0.45923116
#    3.33046536   3.87511403  12.08078837   6.60478893   2.05921887
#    8.81671921   3.97448577   3.47391801   0.79002661  14.98165082
#   54.76305687  92.59573703  82.73041149  49.73669668  69.34936946
#   37.78795224   1.06844393  39.32426448  49.81634816   4.79490472
#   45.1279633  124.38039657 119.33545625  33.51280215  32.09110456
#   13.08794409 186.21652211 113.91248239  35.72911969  31.57935261
#   63.7795231   59.87109539  29.09048559  36.54030416   1.389137
#   66.08383491  54.16952653  60.88094633 131.97142955  17.86989506
#    4.58743166   3.36576224   2.89224887  13.71234359  21.34535105
#    5.09026726   4.57825977   0.69675177   6.15005566  17.75993497
#   10.01654815  33.69680823  21.15594969  72.60989347  19.21563344
#   14.94126079   6.39593617   4.75114313  11.81199648   7.57528947
#    5.66531196   1.6335512   17.22568407   1.77273451   6.76718738]
# 29.568387054608046
# [  0.          67.27482982 266.51821985  89.77073167  20.0261324
#    4.46444101 100.84350565 128.45398262  17.52853327  98.39563511
#   68.50535571  80.28488733 140.3844872   32.73826136   4.70508104
#  172.45548542  71.38943244 104.52035001  52.49667297   1.99943118
#    2.30741187   2.64269969   0.45393416  26.28318938  18.97758005
#    2.86928422  35.11461322  28.307396    24.47657285  26.37938953
#   22.70243231 238.91614346  36.41095756  94.40041519  12.16759554
#   23.77468744   5.99047371  19.93181418 184.56080237   3.95022689
#   47.98925186 218.02998126  26.48584953 250.27863011  86.7332372
#  255.32104523  70.32852275 133.9054325   88.45233886  95.97609523
#   98.29989818  65.72856444 186.71857114  35.25895045  52.74829748
#   25.24464331 108.47908008   0.51393384  36.9278186    3.41677379
#    4.61941229  13.73535163  19.61987993  32.40085026   8.99051759
#    6.49449173   2.93908416  43.9011443    3.93550039  51.30850235
#   56.14776681  19.53449888  42.41034656   9.84656296  95.13710745
#   23.39817436  56.64122602  19.12574577  12.0502233 ]
# 60.03096681339222

# %% [markdown]
# ## LF paw velocity

# %%
### LF paw velocity
LF_paw_np = LF_paw.to_numpy()
LF_paw_np

#LF_paw_np = LF_paw_np[~np.isnan(LF_paw_np)]
LF_paw_np
vel = calc_distance_between_points_in_a_vector_2d(LF_paw_np)

## LF paw Cgroup velocity
LF_paw_Cgroup_np = LF_paw_Cgroup.to_numpy()
LF_paw_Cgroup_np

#LF_paw_Cgroup_np = LF_paw_Cgroup_np[~np.isnan(LF_paw_Cgroup_np)]
LF_paw_Cgroup_np
LF_paw_Cgroup_vel = calc_distance_between_points_in_a_vector_2d(LF_paw_Cgroup_np)

print(LF_paw_Cgroup_vel)
print (np.average(LF_paw_Cgroup_vel))

## LF paw tone velocity
LF_paw_tone_np = LF_paw_tone.to_numpy()
LF_paw_tone_np

#LF_paw_tone_np = LF_paw_tone_np[~np.isnan(LF_paw_tone_np)]
LF_paw_tone_np
LF_paw_tone_vel = calc_distance_between_points_in_a_vector_2d(LF_paw_tone_np)

print(LF_paw_tone_vel)
print (np.average(LF_paw_tone_vel))
# Out:
# [  0.          26.6561291   32.6244315    8.76911447  30.43530223
#    2.99637163  18.41615756  16.4515178   13.92843761  15.00346773
#   13.94653705  30.3603772   58.50433524  36.53464379   5.71104958
#   10.34604044  10.22040722  13.58098394  14.83764979   1.49620976
#    9.50402807   2.75440174  13.82685721   6.21570489  20.3083963
#   48.92362547  88.74384425  57.27644372  47.82032583  47.28677685
#   77.32614935  17.06261027  12.40232836  67.68746608  20.76366759
#   44.2924154  110.75084676  99.24837177  28.52873148  30.93268782
#    3.22508021 202.04743271 149.50316404  16.74263163  66.93091891
#  136.61108967  43.62975717  33.93064725  40.18571504   7.59552521
#   68.05336897  73.73565753  42.74403005 164.04397745  20.61251933
#    6.77037948   1.60559212   0.63116164  33.43933691  37.60529167
#    7.38857491   3.55407238   3.14047479  23.80200521  27.00087572
#   30.5747803   62.17744082  19.80451105  82.84375801  54.87717488
#   26.15818076  20.6483136   11.32436692  20.45675096   9.98063724
#    8.70269434   4.58678507  22.90819578   1.68085186   4.42334952]
# 35.10189892444553
# [  0.          67.90459902 292.76168609 140.7537162   12.07010036
#   43.31146238 139.40983102 155.81333201  18.82647576 116.09735982
#   96.45843471  41.3885404  101.87848607  53.08421011  50.06166549
#  132.91031135  61.21007727 139.25775902  63.07832858  11.02197597
#    1.78055133   5.38071246  13.5903224   30.73819775  19.3944722
#    0.41912276  38.30756544  25.3829734   47.50414787  21.90018608
#   41.62402497 225.55876279   6.42006488 116.53764717   5.36184702
#   18.42607276  20.32876718  22.18180107 212.75642513  33.97282681
#   43.05425139 239.19185759 102.24773418 199.16756398  84.27617544
#  212.61468164  44.78976918 144.57860954  74.72908387 161.23664554
#  116.24606731  81.19474402 185.69915546  41.55840836  69.3973245
#   55.14893875  75.88399569   1.62643442  77.50169444  14.39984975
#   38.81678561  49.2934778   21.73581053  41.17505331  27.42110303
#    6.01286955   3.1296263   47.97738753   5.74499249  58.24227853
#  104.83363058  14.78734008  65.98059943  13.65017883  75.05663313
#   29.74980269  61.57239919  14.67729697  17.1705708 ]
# 67.92956537388987

# %% [markdown]
# ## LR paw velocity

# %%
### LR paw velocity
LR_paw_np = LR_paw.to_numpy()
LR_paw_np

#LR_paw_np = LR_paw_np[~np.isnan(LR_paw_np)]
LR_paw_np
LR_paw_vel = calc_distance_between_points_in_a_vector_2d(LR_paw_np)

## LR paw Cgroup velocity
LR_paw_Cgroup_np = LR_paw_Cgroup.to_numpy()
LR_paw_Cgroup_np

#LR_paw_Cgroup_np = LR_paw_Cgroup_np[~np.isnan(LR_paw_Cgroup_np)]
LR_paw_Cgroup_np
LR_paw_Cgroup_vel = calc_distance_between_points_in_a_vector_2d(LR_paw_Cgroup_np)

print(LR_paw_Cgroup_vel)
print (np.average(LR_paw_Cgroup_vel))

## LR paw tone velocity
LR_paw_tone_np = LR_paw_tone.to_numpy()
LR_paw_tone_np

#LR_paw_tone_np = LR_paw_tone_np[~np.isnan(LR_paw_tone_np)]
LR_paw_tone_np
LR_paw_tone_vel = calc_distance_between_points_in_a_vector_2d(LR_paw_tone_np)

print(LR_paw_tone_vel)
print (np.average(LR_paw_tone_vel))
# Out:
# [  0.          27.06878913  24.87774786  29.31927054   9.05063241
#    8.62355257  11.53006451  15.30521561  10.36771861   5.04887509
#    8.09009732  14.91284736  45.09730212   4.57919606   1.91478107
#    3.37597364   3.71431712   7.57396832   9.47364736   1.50203884
#    3.03670327   0.65899979   3.87282351   2.36138338   2.74683364
#   11.9889877   81.34490684  67.03623165  19.87461498  49.98187556
#   66.69365445   5.18931567  35.7435285    6.2909092   33.95230527
#   29.14902698 106.13972081 108.92977181  29.69376686  19.75649033
#    3.86966133 201.95737284 150.11317244   8.34862888  55.67696641
#   74.75811853  53.23947504  30.73632768  35.21592721   1.67452315
#   62.14918827  44.84328529  55.97925897 113.68926675  20.98803282
#    8.88388788   2.12172661   2.72614855   6.43790909   4.10405898
#    2.59084952   4.18152667   3.27404459  19.2269433   16.73428088
#    4.00695491  16.37941036  23.46587116  75.23951875  45.78071998
#   18.7085435    4.9904899    6.4039255   22.29060473   4.88065486
#    2.37144489   3.07373468  13.62277445   8.71112974   0.31681119]
# 26.995388200178432
# [  0.          32.01030875 254.71186192  84.40318408  23.14297018
#   19.29929317 111.27487089 126.21393747  19.82141127 107.54502839
#   94.59167745  85.34143106 156.57591628  33.48060678  15.66486802
#  135.45531912  36.71584762  80.98184747  66.91799074   6.03789309
#    1.1170171    2.67664043   8.23111722  24.47895946  20.24380792
#    2.4768874   40.91857857  28.91200655  37.92961026  12.73307469
#   11.104265   220.57593088  33.34077261  80.21094449  11.54348983
#   15.40221041  16.93550593  15.68485771 207.19400561  35.48746016
#   39.48068139 238.22454161  47.1643563  231.21648487  85.64502256
#  217.27208119  57.86705826 123.35694462 126.25905825  98.10732636
#  138.14578975  89.86884199 185.53217802  40.68897684  69.44313834
#    7.88216704 102.34544272   6.99375965  39.24887296   3.3309508
#   11.1925194   13.77191729  26.55004305  16.16580485  15.64277132
#    2.54771956   3.27808684  42.62454262   6.25744506  43.41905275
#   48.10440162   8.40286701  47.42434642  13.30505135  72.53600086
#    4.67061274  39.13605476  16.53843826   8.07845608]
# 59.558268498291554

# %%
#non arch EYFP

x = range (80)
y = snout_Cgroup_vel

plt.title('snout velocities')
plt.xlabel('number')
plt.ylabel('velocity')
plt.plot(x, y, color = 'cornflowerblue')
plt.show()


#arch 
x = range (79)
y = snout_tone_vel

plt.title('snout velocities')
plt.xlabel('number')
plt.ylabel('velocity')
plt.plot(x, y, color = 'mediumblue')
plt.show()

# %%
x = range (79)
y = snout_tone_vel

plt.title('snout velocities')
plt.xlabel('number')
plt.ylabel('velocity')
plt.plot(x, y, color = 'mediumblue')
plt.show()

# %%
### rois

#position = namedtuple('position', ['topleft', 'bottomright'])
#rois = {'leftside': position ((0,0), (300, 480))}, {'rightside': position ((300, 0), (640,480))}

#results = {}
#i_start = 1
#i_end = 3

#for bp in bodyparts:
   # df_bp = coordinates.iloc[:, i_start: i_end]
   # df_bp_np = df_bp.to_numpy()
   # df_bp_np = df_bp_np[~np.isnan(df_bp_np)] 
   # vel_bp = calc_distance_between_points_in_a_vector_2d(df_bp_np)
   # bp_tracking = np.array([df_bp_np[:,0], df_bp_np[:,1, vel_np]])
   # res = get_timeinrois_stats(bp_tracking, roi, fps = 30)
   # results[bp] = res
   # i_start = i_start + 2
   # i_end = i_end + 2
    
# results = {}
# for bp in bodyparts:
#     bp_tracking = np.array((tracking.bp.x.values, tracking.bp.y.values, tracking.bp.Velocity.values))
#     res = get_timeinrois_stats(bp_tracking, roi, fps=30)
#     results[bp] = res

# %%
sns.relplot( data = RF_paw_Cgroup , x = 'RF paw (x)', y = 'RF paw (y)', color = 'red')
sns.relplot( data = RF_paw_tone , x = 'RF paw (x)', y = 'RF paw (y)', color = 'green');

plt.show()

# %% [markdown]
# ![sns%20palette.png](attachment:sns%20palette.png)
